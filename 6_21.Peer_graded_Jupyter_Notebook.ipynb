# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Exercise 2 - title of the notebook
# Create a markdown cell with the title of the notebook. (1 pt)

# %% [markdown]
# ## Exercise 3 - Introduction
# Create a markdown cell for an introduction. (1 pt)
# - Notebook for peer graded assignment for IBM data science - tools for data science course

# %% [markdown]
# ## Exercise 4 - List of common data science languages
# Create a markdown cell to list data science languages. (3 pts) <br>
# 1. Python
# 2. SQL
# 3. R
# 4. Scala
# 5. Julia
# 6. C/C++
# 7. Java <br>
# etc.

# %% [markdown]
# ## Exercise 5 - List of data science libraries
# Create a markdown cell to list data science libraries. (3 pts)
# 1. SciKit-Learn
# 2. NumPy
# 3. SciPy
# 4. Matplotlib
# 5. Pandas
# 6. TensorFlow
# 7. Keras
# 8. PyTorch
# 9. Scrapy
# 10. BeautifulSoup <br>
# etc.

# %% [markdown]
# ## Exercise 6 - table of Data Science tools.
# Create a markdown cell with a table of Data Science tools. (3 pts)
# | Tool | Description |
# | --- | --- |
# | Python | High-level programming language with a wide range of libraries and packages for data analysis, machine learning, and visualization |
# | R | Open-source programming language for statistical computing and graphics |
# | SQL | Language for managing and querying relational databases |
# | Tableau | Data visualization tool with a drag-and-drop interface |
# | Excel | Spreadsheet program with basic data analysis and visualization capabilities |
# | Apache Hadoop | Open-source software framework for distributed storage and processing of big data |
# | Apache Spark | Open-source distributed computing system for processing large-scale data |
# | MATLAB | Numerical computing and visualization software |
# | SAS | Analytics and business intelligence software suite |
# | KNIME | Open-source data analytics, reporting, and integration platform |

# %% [markdown]
# ## Excercise 7 - arithmetic expression examples
# Create a markdown cell introducing arithmetic expression examples. (1 pt)
#
# ```python
# # Addition
# 2 + 3
#
# # Subtraction
# 5 - 2
#
# # Multiplication
# 4 * 5
# ```

# %% [markdown]
# ## Exercise 8 - Create a code cell to multiply and add numbers . (2 pts)

# %%
x = 8
y = 2
# Multiplication
print(f"Multiplication: x*y = {x*y}")
# Addition
print(f"Addition: x+y = {x+y}")
# Out:
# Multiplication: x*y = 16
# Addition: x+y = 10

# %% [markdown]
# ## Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

# %%
minutes = 120
hours = minutes / 60
print(f"minutes = {minutes}\nhours = {hours}")
# Out:
# minutes = 120
# hours = 2.0

# %% [markdown]
# ## Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
# **<u>Objectives:</u>** <br>
# 1. Create and Share Your Jupyter Notebook
# 2. Create a markdown cell to list data science languages.
# 3. Create a markdown cell to list data science libraries.
# 4. Create a markdown cell with a table of Data Science tools.
# 5. Create a markdown cell introducing arithmetic expression examples
# 6. Create a code cell to convert minutes to hours.

# %% [markdown]
# ## Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
# ### Author:
# A C.
